# %% [markdown]
# # 🏋 ex4 Python stem-and-leaf

# %% [markdown]
# # stemgraphic
#
# Install `stemgraphic` with:
# ```python
# !pip install -q stemgraphic
# ```
#
# Import `stemgraphic` to get started:

# %%
# !pip install -q stemgraphic
# Out:
# WARNING: You are using pip version 22.0.3; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/meixianwu/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import stemgraphic as sg

# %% [markdown]
# See `?sg.stem_graphic`

# %%
sg.stem_graphic([1, 3, 5, 10, 17, 17])
# Out:
# (<Figure size 540x360 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x7fe5693d02d0>)

# %% [markdown]
# Same using a Pandas dataframe

# %%
import pandas as pd

df = pd.Series([1, 3, 5, 10, 17, 17])

sg.stem_graphic(df)
# Out:
# (<Figure size 540x360 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x7fe569572510>)

# %% [markdown]
# Customizations

# %%
sg.stem_graphic(df, compact=True, asc=False, unit="unit", title="Title")
# Out:
# (<Figure size 540x144 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x7fe56970f250>)

# %% [markdown]
# # Matplotlib stem
#
# `stem` plots vertical lines from a baseline to the y-coordinate and places a marker at the tip (lollipop chart).

# %%
import matplotlib.pyplot as plt

# ?plt.stem

# %% [markdown]
# Example `stem` plot

# %%
plt.stem([1, 3, 5, 10, 17, 17], use_line_collection = True)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Customizations

# %%
plt.rcParams["figure.figsize"] = (2, 2)  #set figure size

plt.stem([1, 3, 5, 10, 17, 17], bottom = 5, use_line_collection = True)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ---
#
# # Exercises

# %% [markdown]
# ## 😜 Exercise 1
#
# - Load `heart-decease.cleveland.csv` in a dataframe
# - Use `stem_graphic` to create a stem-and-leaf plot of the `chol` variable
# - Set `title = 'Cleveland dataset'`
# - Set `unit = 'mg/dl'`
# - Set `asc = False`
# - Set `compact = True`

# %%
import pandas as pd
import stemgraphic as sg

df = pd.read_csv('data/heart-decease-cleveland.csv')

sg.stem_graphic(df.chol, compact=True, asc=False, unit="mg/dl", title="Cleveland dataset")
# Out:
# (<Figure size 540x576 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x7fe569f02550>)

# %% [markdown]
# ## 😜 Exercise 2
#
# - Load `heart-decease.cleveland.csv` in a dataframe
# - Use `matplotlib.pyplot.stem` to create a lollipop chart of the `chol` variable
# - Resize the figure `plt.figure(figsize = (10, 5))`

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/heart-decease-cleveland.csv')

plt.rcParams["figure.figsize"] = (10, 5)  #set figure size

plt.stem(df.chol, use_line_collection = True)
plt.ylabel('chol mg/dl')
# Out:
# Text(0, 0.5, 'chol mg/dl')

# %%
plt.stem(df.chol, bottom = 250,use_line_collection = True)
# Out:
# <StemContainer object of 3 artists>
