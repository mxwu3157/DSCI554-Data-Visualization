# %% [markdown]
# # 🏋 ex7 Python seaborn
#
# Install seaborn with:
# ```python
# !pip install seaborn
# ```
#
# Import [Seaborn](https://seaborn.pydata.org/) and [Pandas](https://pandas.pydata.org/) to get started.

# %%
import numpy as np  #import numpy
import pandas as pd  #import pandas
import seaborn as sns

# %% [markdown]
# Let's load the `iris` dataset:

# %%
iris = pd.read_csv("data/iris.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Scatterplot
#
# This is a minimal scatterplot with iris dataset:

# %%
# ?sns.scatterplot

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Bar chart
# This is a minimal bar chart with `iris` dataset:

# %%
# ?sns.barplot

# %%
iris_counts = iris[['species']].groupby('species').size().reset_index(name='counts')

sns.barplot(x='species', y='counts', data=iris_counts)
# Out:
# <AxesSubplot: xlabel='species', ylabel='counts'>

# %% [markdown]
# Another way to do it:

# %%
#?sns.countplot
sns.countplot(x='species', data=iris_counts)
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %% [markdown]
# # Boxplot
# This is an example of minimal boxplot chart

# %%
# ?sns.boxplot

# %%
sns.boxplot(x='species', y='petal_width', data=iris)
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_width'>

# %% [markdown]
# # Histogram
# Example of a minimal histogram

# %%
# ?sns.distplot

# %%
sns.distplot(iris.petal_width)
# Out:
# /var/folders/8z/055v2l2n3xn_txxmfrttkw_h0000gn/T/ipykernel_49096/2261455277.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris.petal_width)
# <AxesSubplot: xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# # Line chart
#
# See `?sns.lineplot`

# %%
import numpy as np  #import numpy

x = np.linspace(0, 100, 5)
y = x * x

df = pd.DataFrame({
    'x' : x,
    'y' : y
    })

#sns.lineplot(df, 'x','y')
sns.lineplot(data=df, x="x", y="y")
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
import sys
sns.__version__
# Out:
# '0.12.0'

# %% [markdown]
# # Customizations
# - Axis labels
# - Title
# - color
# - Graph size
# - palette
# - point size
# - legend

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,5)

#ax is the axis object!
ax = sns.scatterplot(x='sepal_length',
                     y='sepal_width', 
                     hue='species',  #set color by species 
                     palette='Set2',   #use built-in color palette
                     size='petal_length',  #mark size
                     alpha = 0.5,  #add transparency
                     data=iris)
ax.set(xlabel='sepal length (cm)', 
       ylabel='sepal width (cm)', 
       title ='Iris sepal dimensions')

l = ax.legend()  #set the legend title
l.get_texts()[0].set_text('Legend Name')

# %% [markdown]
# ---
#
# # Exercises

# %% [markdown]
# ## 😜 Exercise 1
#
# Create a scatterplot of the `SMO-VOR-2015.csv` dataset:
#
#  - load `SMO-VOR-2015.csv` in a dataframe
#  - map `x` to `ptime`
#  - map `y` to `alt`
#  - set `alpha` to `0.1`
#  - set `edgecolor` to None
#  - set x axis label to 'Penetration time'
#  - set y axis label to 'Altitude (feets)'
#  - set title label to 'SMO VOR 2015 dataset'
#  - resize the figure to `(10, 5)`
#  - set limits on the axes using `ax.set(xlim=(df.ptime.min(), df.ptime.max()))`

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data/SMO-VOR-2015.csv')
df.ptime = pd.to_datetime(df.ptime)
df

plt.figure(figsize=(10,5))
plt.rcParams["figure.figsize"] = (10,5) 
sns.scatterplot(x='ptime', y='alt', data=df, alpha = 0.1, edgecolor = None)
plt.xlabel('Penetration time')
plt.ylabel('Altitude (feets)')
plt.title('SMO VOR 2015 dataset')
ax.set(xlim=(df.ptime.min(), df.ptime.max()))
# Out:
# [(16495.678680555557, 16785.666238425925)]

# %% [markdown]
# ## 😜 Exercise 2
#
# Create a bar chart of the `SMO-VOR-2015.csv` dataset:
#
#  - load `SMO-VOR-2015.csv` in a dataframe
#  - map `x` to `month`
#  - map `y` to `counts`
#  - set y axis label to 'Count'
#  - set title label to 'SMO VOR 2015 dataset'

# %%
df = pd.read_csv('data/SMO-VOR-2015.csv')
months = ['Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df.month = pd.Categorical(df.month, categories=months, ordered=True)
df = df.groupby(['month']).size().reset_index(name='counts')
sns.barplot(x='month', y='counts', data=df)
plt.ylabel('Count')
plt.title('SMO VOR 2015 dataset')
# Out:
# Text(0.5, 1.0, 'SMO VOR 2015 dataset')

# %% [markdown]
# ## 😜 Exercise 3
#
# Create a boxplot of the `SMO-VOR-2015.csv` by months:
#
#  - load `SMO-VOR-2015.csv` in a dataframe
#  - map `x` to `months`
#  - map `y` to `alt`
#  - set y axis label to 'Altitude (feets)'
#  - set title label to 'SMO VOR 2015 dataset'

# %%
df = pd.read_csv('data/SMO-VOR-2015.csv')
df
sns.boxplot(x='month', y='alt', data=df)
plt.ylabel('Altitude (feets)')
plt.title('SMO VOR 2015 dataset')
# Out:
# Text(0.5, 1.0, 'SMO VOR 2015 dataset')

# %% [markdown]
# ## 😜 Exercise 4
#
# Create an histogram chart of SMO-VOR-2015.csv:
#
# - load `SMO-VOR-2015.csv` in a dataframe
# - set y axis to 'Count'
# - set y axis label to 'Altitude (feets)',
# - set title label to 'SMO VOR 2015 dataset'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data/SMO-VOR-2015.csv')
#plt.rcParams["figure.figsize"] = (10,5) 
plt.figure(figsize=(100,5))
sns.displot(data=df, x="alt", kde=True, aspect=8.7/5.27)
plt.xlabel('Altitude (feets)')
plt.ylabel('Count')

plt.title('SMO VOR 2015 dataset')
# Out:
# Text(0.5, 1.0, 'SMO VOR 2015 dataset')

# %% [markdown]
# ## 😜 Exercise 5
#
# Create a line chart of the `TSLA.csv` dataset:
#
#  - load `TSLA.csv` in a dataframe
#  - map `x` to `Date`
#  - map `y` to `Close`
#  - set `marker` to '.'
#  - set `color` to 'r'
#  - set `linestyle` ':'
#  - set x axis label to ''
#  - set y axis label to 'Stock closure value ($)'
#  - set title label to 'Tesla (TSLA) Jan-Jul 2019'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/TSLA.csv')
df.Date = pd.to_datetime(df.Date)
sns.lineplot(data=df, x="Date", y="Close",
            marker = '.',
             color = 'r',
             linestyle = ':',
            )
plt.title('SMO VOR 2015 dataset')
plt.ylabel('Stock closure value ($)')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')
